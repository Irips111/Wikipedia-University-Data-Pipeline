# %%
import pandas as pd

# %%
df = pd.read_csv('universities.csv', encoding='latin-1')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     71 non-null     str
#  1   University  71 non-null     str
#  2   Founded     71 non-null     str
#  3   Type        71 non-null     str
#  4   Enrollment  71 non-null     str
#  5   Link        71 non-null     str
# dtypes: str(6)
# memory usage: 3.5 KB

# %%
df.head()
# Out:
#      Country                  University Founded    Type Enrollment  \
# 0    Albania        University of Tirana    1957  Public     35,000
# 1    Algeria      Constantine University    1978  Public     85,000
# 2     Angola   Agostinho Neto University    1962  Public     29,827
# 3  Argentina  University of Buenos Aires    1821  Public    311,175
# 4  Australia           Monash University    1958  Public     73,807
#
#                                                 Link
# 0  https://en.wikipedia.org/wiki/University_of_Ti...
# 1  https://en.wikipedia.org/wiki/List_of_universi...
# 2  https://en.wikipedia.org/wiki/Agostinho_Neto_U...
# 3  https://en.wikipedia.org/wiki/University_of_Bu...
# 4    https://en.wikipedia.org/wiki/Monash_University

# %%
df['Founded'].values
# Out:
# <StringArray>
# [    '1957',     '1978',     '1962',     '1821',     '1958',     '1365',
#      '1808',     '1992',     '1921',     '1425',     '1949',     '1982',
#      '1970',     '1888',     '1827',     '1960',     '1867',     '1940',
#      '1669',     '1479',     '1538',     '1950',     '1632',     '1640',
#      '1939',     '1998',     '1837',     '1676',     '1937',     '1911',
#      '1985',     '1984',     '1982',     '1834',     '1956',     '1303',
#      '1889',     '1970',     '1999',     '1579',     '2000',     '1956',
#      '1910',     '1959',     '1636',     '1883',     '1943',     '1996',
#      '1974',     '1551',     '1904',     '1816',     '1288',     '1991',
#      '1992',     '1976',     '1905',     '1919',     '1873',     '1972',
#      '1972',     '1666', '1833[36]',     '1928',     '1971',     '1960',
#      '1958',     '1969',     '1885',     '1949',     '1721']
# Length: 71, dtype: str

# %%
df['Founded'] = df['Founded'].str.extract(r"(\d{4})")

# %%
df['Founded'].values
# Out:
# <StringArray>
# ['1957', '1978', '1962', '1821', '1958', '1365', '1808', '1992', '1921',
#  '1425', '1949', '1982', '1970', '1888', '1827', '1960', '1867', '1940',
#  '1669', '1479', '1538', '1950', '1632', '1640', '1939', '1998', '1837',
#  '1676', '1937', '1911', '1985', '1984', '1982', '1834', '1956', '1303',
#  '1889', '1970', '1999', '1579', '2000', '1956', '1910', '1959', '1636',
#  '1883', '1943', '1996', '1974', '1551', '1904', '1816', '1288', '1991',
#  '1992', '1976', '1905', '1919', '1873', '1972', '1972', '1666', '1833',
#  '1928', '1971', '1960', '1958', '1969', '1885', '1949', '1721']
# Length: 71, dtype: str

# %%
df['Founded'] = df['Founded'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     71 non-null     str
#  1   University  71 non-null     str
#  2   Founded     71 non-null     int64
#  3   Type        71 non-null     str
#  4   Enrollment  71 non-null     str
#  5   Link        71 non-null     str
# dtypes: int64(1), str(5)
# memory usage: 3.5 KB

# %%
df[df['Link'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Country, University, Founded, Type, Enrollment, Link]
# Index: []

# %%
df['Enrollment'].values
# Out:
# <StringArray>
# [                                                                              '35,000',
#                                                                                '85,000',
#                                                                                '29,827',
#                                                                               '311,175',
#                                                                                '73,807',
#                                                                                '91,000',
#                                                                                '90,152',
#                                                                             '2,097,182',
#                                                                                '25,500',
#                                                                                '55,484',
#                                                                                '30,866',
#                                                                                '32,000',
#                                                                               '215,000',
#                                                                                '18 911',
#                                                                               '102,431',
#                                                                                '80,000',
#                                                                                '53,581',
#                                                                                '42,750',
#                                                                                '72,480',
#                                                                             '36,600[1]',
#                                                                               '170,530',
#                                                                               '170,000',
#                                                                                '14,000',
#                                                                                '36,500',
#                                                                           '350,000[10]',
#                                                                               '130,000',
#                                                                               '104,000',
#                                                                               '124,000',
#                                                                                '32,000',
#                                                                                '13,782',
#                                                                             '7,140,000',
#  '1,045,665 (total) as per 2019/2020[16]\n311,028 (active) as per 4 November 2020 [17]',
#                                                                             '1,000,000',
#                                                                                '32,900',
#                                                                                '26,023',
#                                                                               '112,564',
#                                                                                '70,667',
#                                                                                '84,000',
#                                                                                '41,833',
#                                                                                '23,606',
#                                                                                '10,373',
#                                                                               '100,000',
#                                                                               '349,515',
#                                                                               '604,437',
#                                                                                '39,769',
#                                                                                '33,050',
#                                                                                '50,000',
#                                                                                '39,000',
#                                                                             '1,326,266',
#                                                                                '37,032',
#                                                                                '68,249',
#                                                                                '44,400',
#                                                                                '48,100',
#                                                                               '311,928',
#                                                                               '200,000',
#                                                                               '177,234',
#                                                                                '38,300',
#                                                                                '48,821',
#                                                                               '328,179',
#                                                                               '173,758',
#                                                                               '260,079',
#                                                                                '30,646',
#                                                                                '26,356',
#                                                                                '31,758',
#                                                                               '525,000',
#                                                                               '60,000+',
#                                                                             '1,969,733',
#                                                                               '253,075',
#                                                                               '194,000',
#                                                                               '144,108',
#                                                                                '41,059']
# Length: 71, dtype: str

# %%
df['Enrollment'] = df['Enrollment'].str.replace(' ', ',')

# %%
df['Enrollment'].values
# Out:
# <StringArray>
# [                                                                              '35,000',
#                                                                                '85,000',
#                                                                                '29,827',
#                                                                               '311,175',
#                                                                                '73,807',
#                                                                                '91,000',
#                                                                                '90,152',
#                                                                             '2,097,182',
#                                                                                '25,500',
#                                                                                '55,484',
#                                                                                '30,866',
#                                                                                '32,000',
#                                                                               '215,000',
#                                                                                '18,911',
#                                                                               '102,431',
#                                                                                '80,000',
#                                                                                '53,581',
#                                                                                '42,750',
#                                                                                '72,480',
#                                                                             '36,600[1]',
#                                                                               '170,530',
#                                                                               '170,000',
#                                                                                '14,000',
#                                                                                '36,500',
#                                                                           '350,000[10]',
#                                                                               '130,000',
#                                                                               '104,000',
#                                                                               '124,000',
#                                                                                '32,000',
#                                                                                '13,782',
#                                                                             '7,140,000',
#  '1,045,665,(total),as,per,2019/2020[16]\n311,028,(active),as,per,4,November,2020,[17]',
#                                                                             '1,000,000',
#                                                                                '32,900',
#                                                                                '26,023',
#                                                                               '112,564',
#                                                                                '70,667',
#                                                                                '84,000',
#                                                                                '41,833',
#                                                                                '23,606',
#                                                                                '10,373',
#                                                                               '100,000',
#                                                                               '349,515',
#                                                                               '604,437',
#                                                                                '39,769',
#                                                                                '33,050',
#                                                                                '50,000',
#                                                                                '39,000',
#                                                                             '1,326,266',
#                                                                                '37,032',
#                                                                                '68,249',
#                                                                                '44,400',
#                                                                                '48,100',
#                                                                               '311,928',
#                                                                               '200,000',
#                                                                               '177,234',
#                                                                                '38,300',
#                                                                                '48,821',
#                                                                               '328,179',
#                                                                               '173,758',
#                                                                               '260,079',
#                                                                                '30,646',
#                                                                                '26,356',
#                                                                                '31,758',
#                                                                               '525,000',
#                                                                               '60,000+',
#                                                                             '1,969,733',
#                                                                               '253,075',
#                                                                               '194,000',
#                                                                               '144,108',
#                                                                                '41,059']
# Length: 71, dtype: str

# %%
df['Enrollment'] = df['Enrollment'].str.extract(r"(\d{1,3}(?:,\d{1,3})*)")

# %%
df['Enrollment'].values
# Out:
# <StringArray>
# [   '35,000',    '85,000',    '29,827',   '311,175',    '73,807',    '91,000',
#     '90,152', '2,097,182',    '25,500',    '55,484',    '30,866',    '32,000',
#    '215,000',    '18,911',   '102,431',    '80,000',    '53,581',    '42,750',
#     '72,480',    '36,600',   '170,530',   '170,000',    '14,000',    '36,500',
#    '350,000',   '130,000',   '104,000',   '124,000',    '32,000',    '13,782',
#  '7,140,000', '1,045,665', '1,000,000',    '32,900',    '26,023',   '112,564',
#     '70,667',    '84,000',    '41,833',    '23,606',    '10,373',   '100,000',
#    '349,515',   '604,437',    '39,769',    '33,050',    '50,000',    '39,000',
#  '1,326,266',    '37,032',    '68,249',    '44,400',    '48,100',   '311,928',
#    '200,000',   '177,234',    '38,300',    '48,821',   '328,179',   '173,758',
#    '260,079',    '30,646',    '26,356',    '31,758',   '525,000',    '60,000',
#  '1,969,733',   '253,075',   '194,000',   '144,108',    '41,059']
# Length: 71, dtype: str

# %%
df['Enrollment'] = df['Enrollment'].str.replace(',', '')

# %%
df.head()
# Out:
#      Country                  University  Founded    Type Enrollment  \
# 0    Albania        University of Tirana     1957  Public      35000
# 1    Algeria      Constantine University     1978  Public      85000
# 2     Angola   Agostinho Neto University     1962  Public      29827
# 3  Argentina  University of Buenos Aires     1821  Public     311175
# 4  Australia           Monash University     1958  Public      73807
#
#                                                 Link
# 0  https://en.wikipedia.org/wiki/University_of_Ti...
# 1  https://en.wikipedia.org/wiki/List_of_universi...
# 2  https://en.wikipedia.org/wiki/Agostinho_Neto_U...
# 3  https://en.wikipedia.org/wiki/University_of_Bu...
# 4    https://en.wikipedia.org/wiki/Monash_University

# %%
df['Enrollment'] = df['Enrollment'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     71 non-null     str
#  1   University  71 non-null     str
#  2   Founded     71 non-null     int64
#  3   Type        71 non-null     str
#  4   Enrollment  71 non-null     int64
#  5   Link        71 non-null     str
# dtypes: int64(2), str(4)
# memory usage: 3.5 KB

# %%
df
# Out:
#            Country                        University  Founded    Type  \
# 0          Albania              University of Tirana     1957  Public
# 1          Algeria            Constantine University     1978  Public
# 2           Angola         Agostinho Neto University     1962  Public
# 3        Argentina        University of Buenos Aires     1821  Public
# 4        Australia                 Monash University     1958  Public
# ..             ...                               ...      ...     ...
# 66          Turkey                Anadolu University     1958  Public
# 67  United Kingdom                   Open University     1969  Public
# 68   United States          Arizona State University     1885  Public
# 69         Uruguay        University of the Republic     1949  Public
# 70       Venezuela  Universidad Central de Venezuela     1721  Public
#
#     Enrollment                                               Link
# 0        35000  https://en.wikipedia.org/wiki/University_of_Ti...
# 1        85000  https://en.wikipedia.org/wiki/List_of_universi...
# 2        29827  https://en.wikipedia.org/wiki/Agostinho_Neto_U...
# 3       311175  https://en.wikipedia.org/wiki/University_of_Bu...
# 4        73807    https://en.wikipedia.org/wiki/Monash_University
# ..         ...                                                ...
# 66     1969733   https://en.wikipedia.org/wiki/Anadolu_University
# 67      253075      https://en.wikipedia.org/wiki/Open_University
# 68      194000  https://en.wikipedia.org/wiki/Arizona_State_Un...
# 69      144108  https://en.wikipedia.org/wiki/University_of_th...
# 70       41059  https://en.wikipedia.org/wiki/Universidad_Cent...
#
# [71 rows x 6 columns]

# %%
df.to_csv('universities-clean.csv', index=False)
